# %%
import pandas as pd
import io
import requests
# Out:
# Using TensorFlow backend.

# %%
df = pd.read_csv('Consumer_Complaints_small.csv')
df.head()

df.head()
# Out:
#   Date received           Product     Sub-product  \
# 0    03/12/2014          Mortgage  Other mortgage
# 1    10/01/2016  Credit reporting             NaN
# 2    10/17/2016     Consumer Loan    Vehicle loan
# 3    06/08/2014       Credit card             NaN
# 4    09/13/2014   Debt collection     Credit card
#
#                                       Issue                   Sub-issue  \
# 0  Loan modification,collection,foreclosure                         NaN
# 1    Incorrect information on credit report              Account status
# 2                Managing the loan or lease                         NaN
# 3                                Bankruptcy                         NaN
# 4                     Communication tactics  Frequent or repeated calls
#
#                         Consumer complaint narrative  \
# 0                                                NaN
# 1  I have outdated information on my credit repor...
# 2  I purchased a new car on XXXX XXXX. The car de...
# 3                                                NaN
# 4                                                NaN
#
#                              Company public response  \
# 0                                                NaN
# 1  Company has responded to the consumer and the ...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                   Company State ZIP code            Tags  \
# 0                    M&T BANK CORPORATION    MI    48382             NaN
# 1  TRANSUNION INTERMEDIATE HOLDINGS, INC.    AL    352XX             NaN
# 2          CITIZENS FINANCIAL GROUP, INC.    PA    177XX  Older American
# 3                AMERICAN EXPRESS COMPANY    ID    83854  Older American
# 4                          CITIBANK, N.A.    VA    23233             NaN
#
#   Consumer consent provided? Submitted via Date sent to company  \
# 0                        NaN      Referral           03/17/2014
# 1           Consent provided           Web           10/05/2016
# 2           Consent provided           Web           10/20/2016
# 3                        NaN           Web           06/10/2014
# 4                        NaN           Web           09/13/2014
#
#   Company response to consumer Timely response? Consumer disputed?  \
# 0      Closed with explanation              Yes                 No
# 1      Closed with explanation              Yes                 No
# 2      Closed with explanation              Yes                 No
# 3      Closed with explanation              Yes                Yes
# 4      Closed with explanation              Yes                Yes
#
#    Complaint ID
# 0        759217
# 1       2141773
# 2       2163100
# 3        885638
# 4       1027760

# %%
from io import StringIO

col = ['Product', 'Consumer complaint narrative']
df = df[col]
df = df[pd.notnull(df['Consumer complaint narrative'])]
df.columns = ['Product', 'Consumer_complaint_narrative']
df['category_id'] = df['Product'].factorize()[0]

category_id_df = df[['Product', 'category_id']].drop_duplicates().sort_values('category_id')
category_to_id = dict(category_id_df.values)
id_to_category = dict(category_id_df[['category_id', 'Product']].values)

df.head()
# Out:
#              Product                       Consumer_complaint_narrative  \
# 1   Credit reporting  I have outdated information on my credit repor...
# 2      Consumer Loan  I purchased a new car on XXXX XXXX. The car de...
# 7   Credit reporting  An account on my credit report has a mistaken ...
# 12   Debt collection  This company refuses to provide me verificatio...
# 16   Debt collection  This complaint is in regards to Square Two Fin...
#
#     category_id
# 1             0
# 2             1
# 7             0
# 12            2
# 16            2

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(8,6))
df.groupby('Product').Consumer_complaint_narrative.count().plot.bar(ylim=0)
plt.show()

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(sublinear_tf=True, min_df=5, norm='l2', encoding='latin-1', ngram_range=(1, 2), stop_words='english')
features = tfidf.fit_transform(df.Consumer_complaint_narrative).toarray()
labels = df.category_id

features.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d44fa1fa31ce> in <module>()
#       4 #features = tfidf.fit_transform(df.Consumer_complaint_narrative).toarray()
#       5
# ----> 6 features = tfidf.fit_transform(deepcut.tokenize('ตัดคำได้ดีมาก')).toarray()
#       7
#       8 labels = df.category_id
#
# NameError: name 'deepcut' is not defined

# %%
from sklearn.feature_selection import chi2

import numpy as np
N = 2
for Product, category_id in sorted(category_to_id.items()):
  features_chi2 = chi2(features, labels == category_id)
  indices = np.argsort(features_chi2[0])
  feature_names = np.array(tfidf.get_feature_names())[indices]
  unigrams = [v for v in feature_names if len(v.split(' ')) == 1]
  bigrams = [v for v in feature_names if len(v.split(' ')) == 2]
  print("# '{}':".format(Product))
  print("  . Most correlated unigrams:\n. {}".format('\n. '.join(unigrams[-N:])))
  print("  . Most correlated bigrams:\n. {}".format('\n. '.join(bigrams[-N:])))
# Out:
# # 'Bank account or service':
#   . Most correlated unigrams:
# . bank
# . overdraft
#   . Most correlated bigrams:
# . overdraft fees
# . checking account
# # 'Checking or savings account':
#   . Most correlated unigrams:
# . cd
# . 2018
#   . Most correlated bigrams:
# . connect xxxx
# . did overdraft
# # 'Consumer Loan':
#   . Most correlated unigrams:
# . vehicle
# . car
#   . Most correlated bigrams:
# . santander consumer
# . auto loan
# # 'Credit card':
#   . Most correlated unigrams:
# . rewards
# . card
#   . Most correlated bigrams:
# . american express
# . credit card
# # 'Credit card or prepaid card':
#   . Most correlated unigrams:
# . 2018
# . card
#   . Most correlated bigrams:
# . xx 2018
# . fee reversed
# # 'Credit reporting':
#   . Most correlated unigrams:
# . experian
# . equifax
#   . Most correlated bigrams:
# . equifax xxxx
# . credit report
# # 'Credit reporting, credit repair services, or other personal consumer reports':
#   . Most correlated unigrams:
# . 2018
# . inquiries
#   . Most correlated bigrams:
# . mistakes appear
# . hard inquiries
# # 'Debt collection':
#   . Most correlated unigrams:
# . collection
# . debt
#   . Most correlated bigrams:
# . collect debt
# . collection agency
# # 'Money transfer, virtual currency, or money service':
#   . Most correlated unigrams:
# . bitcoin
# . coinbase
#   . Most correlated bigrams:
# . coinbase xxxx
# . coinbase account
# # 'Money transfers':
#   . Most correlated unigrams:
# . moneygram
# . western
#   . Most correlated bigrams:
# . money transfer
# . western union
# # 'Mortgage':
#   . Most correlated unigrams:
# . modification
# . mortgage
#   . Most correlated bigrams:
# . mortgage company
# . loan modification
# # 'Other financial service':
#   . Most correlated unigrams:
# . certegy
# . lexington
#   . Most correlated bigrams:
# . check cashing
# . lexington law
# # 'Payday loan':
#   . Most correlated unigrams:
# . castle
# . payday
#   . Most correlated bigrams:
# . big picture
# . payday loan
# # 'Payday loan, title loan, or personal loan':
#   . Most correlated unigrams:
# . obligor
# . arbitrate
#   . Most correlated bigrams:
# . rate really
# . desist account
# # 'Prepaid card':
#   . Most correlated unigrams:
# . prepaid
# . rushcard
#   . Most correlated bigrams:
# . prepaid card
# . rush card
# # 'Student loan':
#   . Most correlated unigrams:
# . student
# . navient
#   . Most correlated bigrams:
# . student loans
# . student loan
# # 'Vehicle loan or lease':
#   . Most correlated unigrams:
# . repoed
# . lemon
#   . Most correlated bigrams:
# . totaled insurance
# . agreed contract
# # 'Virtual currency':
#   . Most correlated unigrams:
# . appendix
# . coinbase
#   . Most correlated bigrams:
# . said completed
# . going transferred

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB

X_train, X_test, y_train, y_test = train_test_split(df['Consumer_complaint_narrative'], df['Product'], random_state = 0)
count_vect = CountVectorizer()
X_train_counts = count_vect.fit_transform(X_train)
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)
clf = MultinomialNB().fit(X_train_tfidf, y_train)

# %%
print(clf.predict(count_vect.transform(["This company refuses to provide me verification and validation of debt per my right under the FDCPA. I do not believe this debt is mine."])))
# Out:
# ['Debt collection']

# %%
df[df['Consumer_complaint_narrative'] == "This company refuses to provide me verification and validation of debt per my right under the FDCPA. I do not believe this debt is mine."]
# Out:
#             Product                       Consumer_complaint_narrative  \
# 12  Debt collection  This company refuses to provide me verificatio...
#
#     category_id
# 12            2

# %%
print(clf.predict(count_vect.transform(["I am disputing the inaccurate information the Chex-Systems has on my credit report. I initially submitted a police report on XXXX/XXXX/16 and Chex Systems only deleted the items that I mentioned in the letter and not all the items that were actually listed on the police report. In other words they wanted me to say word for word to them what items were fraudulent. The total disregard of the police report and what accounts that it states that are fraudulent. If they just had paid a little closer attention to the police report I would not been in this position now and they would n't have to research once again. I would like the reported information to be removed : XXXX XXXX XXXX"])))
# Out:
# ['Credit reporting']

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from sklearn.model_selection import cross_val_score

models = [
    RandomForestClassifier(n_estimators=200, max_depth=3, random_state=0),
    LinearSVC(),
    MultinomialNB(),
    LogisticRegression(random_state=0),
]
CV = 5
cv_df = pd.DataFrame(index=range(CV * len(models)))
entries = []
for model in models:
  model_name = model.__class__.__name__
  accuracies = cross_val_score(model, features, labels, scoring='accuracy', cv=CV)
  for fold_idx, accuracy in enumerate(accuracies):
    entries.append((model_name, fold_idx, accuracy))
cv_df = pd.DataFrame(entries, columns=['model_name', 'fold_idx', 'accuracy'])

import seaborn as sns
sns.boxplot(x='model_name', y='accuracy', data=cv_df)
sns.stripplot(x='model_name', y='accuracy', data=cv_df, 
              size=8, jitter=True, edgecolor="gray", linewidth=2)
plt.show()

# %%
cv_df.groupby('model_name').accuracy.mean()
# Out:
# model_name
# LinearSVC                 0.820127
# LogisticRegression        0.798255
# MultinomialNB             0.685485
# RandomForestClassifier    0.330621
# Name: accuracy, dtype: float64

# %%
model = LinearSVC()
X_train, X_test, y_train, y_test, indices_train, indices_test = train_test_split(features, labels, df.index, test_size=0.33, random_state=0)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
from sklearn.metrics import confusion_matrix
conf_mat = confusion_matrix(y_test, y_pred)
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(conf_mat, annot=True, fmt='d',
            xticklabels=category_id_df.Product.values, yticklabels=category_id_df.Product.values)
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()

# %%
from IPython.display import display
for predicted in category_id_df.category_id:
  for actual in category_id_df.category_id:
    if predicted != actual and conf_mat[actual, predicted] >= 10:
      print("'{}' predicted as '{}' : {} examples.".format(id_to_category[actual], id_to_category[predicted], conf_mat[actual, predicted]))
      display(df.loc[indices_test[(y_test == actual) & (y_pred == predicted)]][['Product', 'Consumer_complaint_narrative']])
      print('')
# Out:
# 'Consumer Loan' predicted as 'Credit reporting' : 29 examples.
#               Product                       Consumer_complaint_narrative
# 61449   Consumer Loan  Inaccurate information as well as severe lack ...
# 141886  Consumer Loan  This creditor is stating that account is XXXX ...
# 123825  Consumer Loan  I XXXX XXXX believes that the credit reporting...
# 33829   Consumer Loan  My payment is listed as 30 days late on XXXX c...
# 33855   Consumer Loan  Bought a car in XXXX 2015 and financing was ac...
# 59574   Consumer Loan  I sent the company Balance Credit a revocation...
# 115050  Consumer Loan  I am filing this complaint against TD Auto Fin...
# 40791   Consumer Loan  This company made inquiries to my credit repor...
# 33885   Consumer Loan  Interest rates seemHigher than normal rates ev...
# 86243   Consumer Loan  This duplicate case is in reference to complai...
# 22161   Consumer Loan  Hello Approximately 2 weeks ago I had noticed ...
# 31073   Consumer Loan  I disputed inaccurate information with credit ...
# 40090   Consumer Loan  Balance for XXXX Account # XXXX incorrectly di...
# 130331  Consumer Loan  Hello. Santander Consumer USA has placed an au...
# 140089  Consumer Loan  I have not paid any payments since XXXX 2008 o...
# 19276   Consumer Loan  ONEMAIN # XXXX XXXX , IN XXXX ( XXXX ) XXXX Da...
# 122745  Consumer Loan  XXXX/XXXX/XXXX GM FINANCIAL ACC # XXXX Late Da...
# 21627   Consumer Loan  I was offered a refi on my Audi Q5 when stoppi...
# 16250   Consumer Loan  XXXX XXXX aka NMAC has reported a 30 day late ...
# 137941  Consumer Loan  Account # XXXX XXXX Bank Delaware was paid. Di...
# 82320   Consumer Loan  i received an e-mail alert telling me that a c...
# 93026   Consumer Loan  My daughter asked me to co-sign an auto lease....
# 133926  Consumer Loan  I have never been late on my loan, yet they ar...
# 10044   Consumer Loan  I took out this loan 15 mos ago. At first it s...
# 113962  Consumer Loan  They sent me a bill for excess miles on a leas...
# 36428   Consumer Loan  XXXX XXXX XXXX, acct XXXX .... I submitted doc...
# 2726    Consumer Loan  Quoting them, your first loan application, the...
# 107664  Consumer Loan  I am not really sure what this loan credit inq...
# 83956   Consumer Loan  I got a levy from this company XXXX. It is an ...
# 'Debt collection' predicted as 'Credit reporting' : 104 examples.
#                 Product                       Consumer_complaint_narrative
# 115950  Debt collection  Debt is from XXXX/XXXX/2010 From XXXX XXXX Phy...
# 103927  Debt collection  Reporting erroneously/ incorrectly/ inaccurate...
# 97153   Debt collection  Upon review of my credit report with Experian,...
# 99359   Debt collection  I had a Credit Card with XXXX XXXX. I paid the...
# 11552   Credit card  Bank of America has re aged a charged off acco...
# 76202   Credit card  I have a general complaint about credit card s...
# 124943  Credit card  I am a victim of identity theft from more than...
# 65314   Credit card  I started paying a loan to XXXX back in XXXX. ...
# 50965   Credit card  This account is closed been closed since XX/XX...
# 69116   Credit card  I ran my free credit report today. It shows cr...
# 85212   Credit card  I would like to dispute a Capital one Bank USA...
# 100719  Credit card  I looked at my credit report and seen somethin...
# 128730  Credit card  Ca n't reset password and pay online. Tried to...
# 145450  Credit card  Booked a travel ticket with XXXX XXXX. Immedia...
# 64604   Credit card  XXXX XXXX files dispute. XXXX charged XXXX {$5...
# 23952   Credit card  The Chase account has been reporting on my per...
# 70147   Credit card  I was investigating the fraudulent charges on ...
# 102686  Credit card  Bank of America gave me an incorrect payoff am...
# 103772  Credit card  This company is in direct violation of 15 U.S....
# 126575  Credit card  I paid and settled a credit card account with ...
# 18691   Credit card  I was told this account wiuld be deleted from ...
# 19916   Credit card  Capital One/Kohls has been reporting a past du...
# 21886   Credit card  I have inquiries on my credit report that are ...
# 61983   Credit card  I was denied a credit card from American Expre...
# 39841   Credit card  I have applied for a credit line increase on s...
# 148509  Credit card  Upon reviewing my credit report I noted an XXX...
# 4714    Credit card  American Express is reporting an account on my...
# 12134   Credit card  The Home Depot failed to remove my name, as pr...
# 141752  Credit card  The kohls account has been write off as a debt...
# 20828   Credit card  acct closed under CHP XXXX bankruptcy and stil...
# 109584  Credit card  ON XXXX/XXXX/2014 BARCLAYCARD MADE HARD INQUIR...
# 152305  Credit card  My checking account was debited on the XXXX of...
# 96580   Credit card  Please contact me Brooks Brothers fraudulently...
# 21902   Credit card  To whom this may concern I have been applying ...
# 48120   Credit card  I had a credit card issued by my credit union....
# 22221   Credit card  This account has been paid in full but has not...
# 147540  Credit card  My daughter is an authorized user on my Bank o...
# 'Bank account or service' predicted as 'Credit reporting' : 16 examples.
#                         Product  \
# 128401  Bank account or service
# 45668   Bank account or service
# 88852   Bank account or service
# 74607   Bank account or service
# 126498  Bank account or service
# 39987   Bank account or service
# 47374   Bank account or service
# 488     Bank account or service
# 95450   Bank account or service
# 25790   Bank account or service
# 94897   Bank account or service
# 66812   Bank account or service
# 91728   Bank account or service
# 98973   Bank account or service
# 133299  Bank account or service
# 46968   Bank account or service
#
#                              Consumer_complaint_narrative
# 128401  I opened a XXXX account and when I tried to us...
# 45668   The problem is with EXPERIANTo know my score I...
# 88852   someone opened an account with Bb & t it was n...
# 74607   Chexsystems is reporting that I have some kind...
# 126498  Good morning, I retrieved my credit report and...
# 39987   I was an authorized user on my husband 's acco...
# 47374   Experian ( a client of XXXX ) was hacked. Lack...
# 488     I submitted a complaint in XX/XX/XXXX regardin...
# 95450   CHEXSYSTEMS HAS FAILED TO REMOVE ALL NEGATIVE ...
# 25790   I have been trying since XXXX to get XXXX hard...
# 94897   I have been reported to ews by XXXX XXXX XXXX,...
# 66812   This is a complaint against Branch Banking & T...
# 91728   XXXX XXXX XXXX XXXX XXXX XXXX XXXX VA XXXX SS ...
# 116601  Statement to File w ith Credit union  disputes...
# 111978  I have disputed this account with 3 credit bur...
# 87241   Equifax has not been allowing me to get a repo...
# 6820    On XX/XX/XXXX, I contacted XXXX XXXX XXXX and ...
# 72625   wrongful eviction stated on my credit showing ...
# 41011   In early XX/XX/XXXX I mailed following request...
# 95906   My identity was stolen between XX/XX/XXXX-XX/X...
# 116473  I mailed a  Multiply Inquiry  Removal Letter  ...
# 151668  A bit of historyI was a victim of identity the...
# 112365  Frauding scams using XXXX Indiana and XXXX Ind...
# 70833   There is a hard inquiry on my credit report th...
# 94937   I have tried multiple times to contact trans U...
# 61448   I was denied a loan and received a copy of my ...
# 117411  A  XXXX  's credit card account is now appeari...
# 101694  Did not handle our situation today XX/XX/2018!...
# 104780  I am a victim of identity theft. The informati...
# 73805   2 years ago we placed a freeze on our credit w...
# 87573   On XX/XX/XXXX I sent a certified letter to Exp...
# 117529  There are numerous addresses and employers tha...
# 73737   Dear TransUnion, Please remove the following n...
#
# [151 rows x 2 columns]
# 'Credit reporting' predicted as 'Consumer Loan' : 23 examples.
#                  Product                       Consumer_complaint_narrative
# 16922   Credit reporting  the XXXX sold me a car later they do n't want ...
# 132631  Credit reporting  Why was this loan removed from my Credit Repor...
# 84795   Credit reporting  I 'm a victim of identity theft and the compan...
# 53770   Credit reporting  My issue is with a car lease. The car was not ...
# 7473    Credit reporting  On XXXX/XXXX/XXXX I gave permission for Capita...
# 56391   Credit reporting  I had a loan financed through XXXX XX/XX/2015 ...
# 51453   Credit reporting  As part of our divorce settlement, my ex wife ...
# 47538   Credit reporting  XXXX have potentially negative on my account e...
# 29162   Credit reporting  I applied for a online loan a few years ago, a...
# 57184   Credit reporting  I have reached out to the credit bureaus about...
# 152031  Credit reporting  XXXX merged my account with someone who has al...
# 82326   Credit reporting  My auto loan through ally XXXX XXXX is in good...
# 49935   Credit reporting  It has been XXXX months since I filed a compla...
# 42760   Credit reporting  I had a vehicle Financed through XXXX XXXX. I ...
# 86135   Credit reporting  On my credit reports ( XXXX and Transunion ) i...
# 103555  Credit reporting  I had a loan with XXXX XXXX auto financing for...
# 112554  Credit reporting  This company XXXX just bought my loan in the p...
# 93620   Credit reporting  I have a hard inquiry on my credit report from...
# 146613  Credit reporting  I 'm XXXX years old. I have a full time steady...
# 71146   Credit reporting  I traded in 2013 XXXX XXXX that was financed w...
# 84706   Credit reporting  Hi, My Name is XXXX XXXX. I am having problems...
# 24224   Credit reporting  I went into a dealership and asked that they o...
# 55769   Credit reporting  THE CREDITOR SUN LOAN DID NOT APPLY MY PAYMENT...
# 'Debt collection' predicted as 'Consumer Loan' : 29 examples.
#                 Product                       Consumer_complaint_narrative
# 122374  Debt collection  I am submitting a complaint against Freedom Ac...
# 2969    Debt collection  There was not an option that fit my situation....
# 149829  Debt collection  I recently had repossession of my vehicle, The...
# 140665  Debt collection  I had filed a complaint with the CFPB and they...
# 123403  Debt collection  I defaulted on this loan almost two years ago....
# 123405  Bank account or service
# 135849  Bank account or service
# 23179   Bank account or service
# 77013   Bank account or service
# 146116  Bank account or service
# 147860  Bank account or service
# 120441  Bank account or service
# 64040   Bank account or service
#
#                              Consumer_complaint_narrative
# 46638   In XX/XX/XXXX I was given a loan by Citizens B...
# 130740  On XX/XX/XXXX I ordered XXXX cashier 's checks...
# 123405  I checked my credit monitoring report via XXXX...
# 135849  We finance a bed bought at XXXX in XXXX 2014. ...
# 23179   I received a letter from Ally Bank indicating ...
# 77013   I viewed my credit report and find a lender " ...
# 146116  TITLE : Wells Fargo : I had an account with a ...
# 147860  I fell victim to the housing crisis like many ...
# 120441  The issues we have with USAA BANK/CREDIT CARD/...
# 64040   I received a call from a company in California...
# 'Payday loan' predicted as 'Consumer Loan' : 18 examples.
#             Product                       Consumer_complaint_narrative
# 53573   Payday loan  Could n't pay a loan company for a loan due to...
# 33577   Payday loan  I borrowed XXXX in 2012, I have already paid b...
# 135663  Payday loan  I have had a loan with Rise Credit for over a ...
# 103175  Payday loan  Received a check for {$1200.00} from Republic ...
# 30583   Payday loan  I took a loan from XXXX XXXX XXXX based on an ...
# 125310  Payday loan  I paid the loan off it was {$7500.00}, now the...
# 107196  Payday loan  i had a loan at western finance in XXXX texas....
# 97011   Payday loan  XXXX on XXXX, WA XXXX. I took out a payday loa...
# 153327  Payday loan  In XX/XX/2013 I took a loan from Western Sky. ...
# 5565    Payday loan  I have a loan through a loan company and they ...
# 133082  Payday loan  I took out a Spot Loan in XXXX XXXX. The loan ...
# 21677   Payday loan  I was in need of a loan so I called and applie...
# 3972    Payday loan  hi. i have loaned money from ace cash express ...
# 117994  Payday loan  I took out a loan from Cash Call XXXX 2014 for...
# 66605   Payday loan  XX/XX/XXXX I applied for a loan with loanme.co...
# 124557  Payday loan  I had an Loan with cash call and paid them way...
# 114085  Payday loan  To whom  it may con cern, I 'd like to make a ...
# 28706   Payday loan  Today XXXX/XXXX/2016 at XXXX XXXX XXXX from Ac...
# 'Vehicle loan or lease' predicted as 'Consumer Loan' : 12 examples.
#                       Product  \
# 113024  Vehicle loan or lease
# 88920   Vehicle loan or lease
# 103738  Vehicle loan or lease
# 115196  Vehicle loan or lease
# 104185  Vehicle loan or lease
# 97083   Vehicle loan or lease
# 70683   Vehicle loan or lease
# 105044  Vehicle loan or lease
# 89103   Vehicle loan or lease
# 69854   Vehicle loan or lease
# 100188  Vehicle loan or lease
# 32411   Vehicle loan or lease
#
#                              Consumer_complaint_narrative
# 113024  I have contacted suntrust by mail asking for v...
# 88920   On XX/XX/XXXX i submitted a agreed payoff amou...
# 103738  United Acceptance  is reporting this vehicle, ...
# 115196  I Filed a complaint # XXXX on BRIDGECREST ACCE...
# 104185  We voluntarily surrerendered our   XXXX     XX...
# 97083   I've been with this thieving company since 201...
# 70683   XXXX XXXX I purchased a vehicle from XXXX a XX...
# 105044  There are times when I paid late. And of cours...
# 89103   I've had that displeasure of dealing with XXXX...
# 69854   I have been harrassed non stop by phone, text ...
# 100188  This account was paid in full from a insurance...
# 32411   I contacted XXXX XXXX XXXX to have my extended...
# 'Credit reporting' predicted as 'Debt collection' : 195 examples.
#                  Product                       Consumer_complaint_narrative
# 115153  Credit reporting  I pa id one of m y debts listed in my credit r...
# 49104   Credit reporting  ACCOUNT RESOLUTION SERVICE # XXXXI have a a un...
# 99193   Credit reporting  I have a judgment on my credit report that was...
# 65648   Credit reporting  Hello, I have checked my credit score using XX...
# 123254  Credit reporting  This account has been moved to the state of Id...
# 93681   Credit reporting  I believed some of the information on my credi...
# 95255   Credit reporting  On XXXX XXXX, 2015, we tendered proper notice ...
# 116370  Credit reporting  I have a debt reporting on my credit for a pay...
# 29205   Credit reporting  I have come to the understanding that Syndicat...
# 82997   Credit reporting  I have a derogatory remark on my credit report...
# 143909  Credit reporting  I put a dispute countless times XXXX got the s...
# 126237  Credit reporting  Keep getting alerts that my Barclays account i...
# 80664   Credit reporting  I want to dispute a collection posted in my cr...
# 19690   Credit reporting  XXXX sent XXXX phone bills to collection which...
# 97330   Credit reporting  Reporting/collecting unverified/unvalidated de...
# 104244  Credit reporting  XXXX XXXX XXXX placed a collection on my Exper...
# 79015   Credit reporting  There are a couple medical debts listed which ...
# 17294   Credit reporting  I had a XXXX in XXXX 2015 while living in XXXX...
# 19339   Credit reporting  My credit report shows I have an outstanding d...
# 114874  Credit reporting  XXXX   XXXX   is fraudulent someone used my i....
# 141630  Credit reporting  XXXX has recently authorized a credit pull wit...
# 28060   Credit reporting  There has been a judgment on my credit report ...
# 35225   Credit reporting  This company said they would remove the false ...
# 63536   Credit reporting  The below letters shows XXXX of many attempts ...
# 81496   Credit reporting  Due to the fact that my situation is not above...
# 45813   Credit reporting  XXXX started reporting a collection that is ou...
# 116325  Credit reporting  At the beginning of  XXXX  I started receiving...
# 19847   Credit reporting  BYL collection services XXXX XXXX PA, XXXX XXX...
# 87447   Credit reporting  XXXX has not sent my request of a signed valid...
# 18547   Credit reporting  XXXX XXXX, XXXX a Class Action Suit In the XXX...
# ...                  ...                                                ...
# 105199  Credit reporting  I was applying for an auto loan. Auto loan was...
# 11708   Credit reporting  They ran my credit with out my authorization.....
# 52369   Credit reporting  I rented an apartment to XXXX XXXX managed by ...
# 82965   Credit reporting  This is for a phone bill that I do n't believe...
# 140833  Credit reporting  There is an account XXXX a collection account....
# 35477   Credit reporting  I rented an apartment XX/XX/XXXX with a friend...
# 23913   Credit reporting  They are allowing XXXX XXXX to duplicate an ac...
# 62128   Credit reporting  This account has pass the statue of reporting ...
# 126252  Credit reporting  XXXX XXXX XXXX has reported on two occasions w...
# 141496  Credit reporting  XXXX XXXX fraudulently changed there promotion...
# 85450   Credit reporting  XXXX XXXX XXXX caeds from XXXX popped up on my...
# 136868  Credit reporting  XXXX account opened by my wife & paid by her w...
# 60802   Credit reporting  There are XXXX accounts that affecting my cred...
# 141574  Credit reporting  I received a letter from Citibank stating that...
# 47969   Credit reporting  I was a customer of XXXX. After XXXX bought XX...
# ...             ...                                                ...
# 40067   Credit card  This company lied about a promotion of not cha...
# 10745   Credit card  I have been receiving bills for care credit. I...
# 6699    Credit card  I did not receive the last bill for purchases ...
# 8555    Credit card  previous Case number : XXXX I would like to re...
# 14424   Credit card  I actually have quite a few complaints about R...
# 80169   Credit card  I paid a {$11000.00} fee and forfeited {$XXXX}...
# 150645  Credit card  Tried to utilize a debt consolidation company ...
# 65061   Credit card  This is an very old debt that is still showing...
# 27458   Credit card  Acceptance Rentals this company operates and t...
# 116970  Credit card  I received a phone call from a female  XXXX  s...
# 128508  Credit card  I opened a credit card account with Ashley Fur...
# 45581   Credit card  I 'm a XXXX vounterable adult and I have a iss...
# 19975   Credit card  I had filed an FCRA lawsuit with attorney XXXX...
# 76793   Credit card  My wife had accrued over a thousand dollars in...
# 76829   Credit card  I do not recognize this account it is not mine...
# 78062   Credit card  I sent Bank of America a letter XXXX XXXX, XXX...
# 147796  Credit card  Home Depot is charging me unfair finance charg...
# ...
# 'Money transfers' predicted as 'Bank account or service' : 22 examples.
#                 Product                       Consumer_complaint_narrative
# 134441  Money transfers  As a favor to a friend, I setup a Chase Quick ...
# 86738   Money transfers  On XXXX XXXX, XXXX, I was left a message on my...
# 8810    Money transfers  I became friends with a gentlemen I met on XXX...
# 19101   Money transfers  I transferred {$5000.00} to XXXX of which bank...
# 110562  Money transfers  At or around  XXXX  I visited Pay-O-Matic to s...
# 103033  Money transfers  I have an online account with Bank of America ...
# 23756   Money transfers  I transferred {$650.00} using Wells Fargo Sure...
# 18736   Money transfers  I noticed XXXX unauthorized charges were made ...
# 19765   Money transfers  On XX/XX/XXXX I thought I had transferred {$19...
# 105597  Money transfers  was issued a check via mail, to deposit into a...
# 53385   Money transfers  I opened an account with Skrill ( https : //ww...
# 123341  Money transfers  I am a customer of Bank of America. Whenever I...
# 134922  Money transfers  CFPB Complaint Number : XXXX XXXX Police Dept....
# 130948  Money transfers  I am a customer of PNC Bank. I transferred {$1...
# 86923   Money transfers  On XXXX XXXX, 2015 I initiated a money transfe...
# 61046   Money transfers  On the XXXX we had a scam phone call from " IR...
# 144947  Money transfers  i sent {$750.00} to a friend of mine on paypal...
# 31464   Money transfers  Good Day my name is XXXX I am filing a complai...
# 117879  Money transfers  I want to depute a wire international transfer...
# 33222   Money transfers  On XX/XX/2014 XXXX XXXX was to receive a wire ...
# 116462  Money transfers  I did log in to my PayPal account to transfet ...
# 112539  Money transfers  I was notified b y Paypal o n  XXXX    XXXX   ...
# 'Prepaid card' predicted as 'Bank account or service' : 19 examples.
#              Product                       Consumer_complaint_narrative
# 130053  Prepaid card  I ordered a XXXX Tablet for {$53.00} at XXXX o...
# 121105  Prepaid card  I am trying to transfer money to another accou...
# 70045   Prepaid card  I am contacting you in regards to a dispute be...
# 76891   Prepaid card  Has not posted my direct deposit in the amount...
# 36359   Prepaid card                      They add fees to this account
# 115960  Prepaid card  Hello, I recently set up my first online busin...
# 19937   Prepaid card  I am entitled to XXXX payments relating to Pai...
# 92247   Prepaid card  I am a Colorado resident. I have a {$100.00} V...
# 48573   Prepaid card  Unauthorized charges on my account disputing b...
# 101905  Prepaid card  My daughter gave me a Mastercard Debit Card ( ...
# 69973   Prepaid card  Paypal took action to close my account but ref...
# 8166    Prepaid card  my debit card direct express debit card which ...
# 137564  Prepaid card  I signed up with net spend and then signed up ...
# 110558  Prepaid card  I am the son of  XXXX   XXXX . I opened a net ...
# 147825  Prepaid card  I have Bank of America pre paid debit card tha...
# 15365   Prepaid card  XXXX of XXXX XXXX ( XXXX minutes ago ) To whom...
# 86392   Prepaid card  I ca n't access my account because it says my ...
# 106300  Prepaid card  This company is holding my funds in the amount...
# 114678  Prepaid card  I am the XXXX for my son 's SSI benefits via t...
# 'Checking or savings account' predicted as 'Bank account or service' : 44 examples.
#                             Product  \
# 22329   Checking or savings account
# 117744  Checking or savings account
# 106291  Checking or savings account
# 106512  Checking or savings account
# 50643   Checking or savings account
# 75221   Checking or savings account
# 63924   Checking or savings account
# 85522   Checking or savings account
# 10418   Checking or savings account
# 89404   Checking or savings account
# 76244   Checking or savings account
# 107083  Checking or savings account
# 118984  Checking or savings account
# 91662   Checking or savings account
# 90498   Checking or savings account
# 70752   Checking or savings account
# 88039   Checking or savings account
# 90961   Checking or savings account
# 50211   Checking or savings account
# 70081   Checking or savings account
# 81757   Checking or savings account
# 94765   Checking or savings account
# 91538   Checking or savings account
# 67182   Checking or savings account
# 105150  Checking or savings account
# 115047  Checking or savings account
# 106342  Checking or savings account
# 98045   Checking or savings account
# 64305   Checking or savings account
# 114414  Checking or savings account
# 32766   Checking or savings account
# 108706  Checking or savings account
# 4098    Checking or savings account
# 62000   Checking or savings account
# 115216  Checking or savings account
# 54973   Checking or savings account
# 108339  Checking or savings account
# 104454  Checking or savings account
# 109549  Checking or savings account
# 114065  Checking or savings account
# 101175  Checking or savings account
# 75448   Checking or savings account
# 69724   Checking or savings account
# 100015  Checking or savings account
#
#                              Consumer_complaint_narrative
# 22329   I noticed that we had many ATM withdraws that ...
# 117744  I received an alert fro m the discover indi ca...
# 106291  I made a payment to navy federal credit union ...
# 106512  On XX/XX/18 at XXXX, I received a phone call f...
# 50643   The company I bank with, Wells Fargo, won't st...
# 75221   In XX/XX/XXXX, National Bank of Arizona ( NBA ...
# 63924   On XX/XX/XXXX, I contacted Bank of America to ...
# 85522   I had a checking account with USAA and insuran...
# 10418   XX/XX/2018 I receive this deposits in my accou...
# 89404   In the 1920 's my great grand father establish...
# 76244   A check for {$960.00}, written by an insurance...
# 107083  I lost my money in Debit card And I dont know ...
# 118984  Wachovia became Wells Fargo.\nWachovia r  emov...
# 91662   In XX/XX/XXXX, I moved to XXXX XXXX from XXXX ...
# 90498   Hello, I received a phone call on Friday XX/XX...
# 70752   My account was not over drawn as I checked wit...
# 88039   On XX/XX/XXXXor XX/XX/2018, I requested my ban...
# 90961   Wells Fargo account ending in XXXX reflected a...
# 90487   Consumer Loan  On XXXX/XXXX/15 went into a XXXX store in XXXX...
# 118385  Consumer Loan  I visited a local loan provider to apply for a...
# 7989    Consumer Loan  I have never had a late payment and Wells Farg...
# 133899  Consumer Loan  on XXXX/XXXX/2016 requested information about ...
# 'Debt collection' predicted as 'Student loan' : 29 examples.
#                 Product                       Consumer_complaint_narrative
# 99739   Debt collection  NES is attempting to collect on loans that wer...
# 55038   Debt collection  I was stupid when I was younger I believed the...
# 15675   Debt collection  I attended University XXXX a few years ago. Th...
# 27265   Debt collection  On XX/XX/XXXX my daughter started an Applicati...
# 105634  Debt collection  XXXX, College Assist had XXXX contact me about...
# 434     Debt collection  The Indiana Department of Revenue contacted me...
# 14446   Debt collection  Clearview Resolution Services XXXX lied to my ...
# 49080   Debt collection  XXXX XXXX XXXX had threaten me with a garnishm...
# 11362   Debt collection  I had consolidated my federal student loans an...
# 105486  Debt collection  After reviewing all of my student loans online...
# 10888   Debt collection  On XXXX XXXX, 2015 I enrolled in a online cour...
# 54847   Debt collection  I was in school and was involved in a XXXX acc...
# 104590  Debt collection  I attended a College called  XXXX   XXXX   XXX...
# 65574   Debt collection  This collector is harassing me at work and sta...
# 87590   Debt collection  AES 's automated system does not give you the ...
# 25091   Debt collection  I have requested 5 times that Navient not call...
# 76144   Debt collection  They call several times a day. After I do not ...
# 99371   Debt collection  XXXX XXXX I was approved on an individual basi...
# 26829   Debt collection  In addition to the disputes currently on recor...
# 12943   Debt collection  I am disputing this issue with Navient, but am...
# 54074   Debt collection  Navient continues to say I owe a XX/XX/XXXX pa...
# 82047   Debt collection  National Collegiate Student Loan Trust is a tr...
# 110428  Debt collection  Student Advocates as well as equitable accepta...
# 393     Debt collection  XXXX University under the XXXX XXXX umbrella s...
# 140705  Debt collection  I have a forbearance on the debt until XX/XX/X...
# 84082   Debt collection  A collector at DCS ( named XXXX XXXX ) contact...
# 119426  Debt collection  Received communication from Enterprise Recover...
# 150341  Debt collection  I have a student loan with Sallie Mae. I have ...
# 65436   Debt collection  I dispute the entire amount of student loans s...
# 'Bank account or service' predicted as 'Prepaid card' : 18 examples.
#                         Product  \
# 27429   Bank account or service
# 124818  Bank account or service
# 17587   Bank account or service
# 7165    Bank account or service
# 48805   Bank account or service
# 66847   Bank account or service
# 47447   Bank account or service
# 7946    Bank account or service
# 31962   Bank account or service
# 152821  Bank account or service
# 146977  Bank account or service
# 126335  Bank account or service
# 13698   Bank account or service
# 87989   Bank account or service
# 113170  Bank account or service
# 55508   Bank account or service
# 33519   Bank account or service
# 148894  Bank account or service
#
#                              Consumer_complaint_narrative
# 27429   I received a Netspend Premier Prepaid Card fro...
# 124818  XXXX of my prepaid debit visa gift card issued...
# 17587   I put money on my Rush Card, went to use it an...
# 7165    pay pal prepaid works with net spend and they ...
# 48805   Rushcard took my money didnt allow me access t...
# 66847   I am a Rushcard victim who has not been able t...
# 47447   I am one of the many affected by the RushCard ...
# 7946    rush card, stated that there was computer main...
# 31962   XX/XX/XXXX - I performed a cash load of {$2500...
# 152821  PayPal locked my account and will not give me ...
# 146977  Rush card sent text messages telling all custo...
# 126335  I use American Express Bluebird for my direct ...
# 13698   The Rush Card has been with holding money from...
# 87989   I am a rush card customer and I called to repl...
# 113170  I have a Rushcard and my pay is deposited twic...
# 55508   I filed my income tax return via XXXX. I was o...
# 33519   My employer direct deposited my payroll check ...
# 148894  Do to rushcard my bills are being late and im ...
# 'Credit reporting' predicted as 'Credit reporting, credit repair services, or other personal consumer reports' : 18 examples.
#                  Product                       Consumer_complaint_narrative
# 1585    Credit reporting  Had a car loan with XXXX XXXX XXXX, which was ...
# 8408    Credit reporting  The following inquires on my credit report wer...
# 115060  Credit reporting  Hi, My name is XXXX XXXX XXXX. My address is :...
# 143614  Credit reporting  Unauthorized credit Inquiry on XX/XX/2017 Cred...
# 65085   Credit reporting  Hard inquiry on my account that I did not auth...
# 123914  Credit reporting  Fraudulent accounts/Identity theft- XXXX XXXX-...
# 80953   Credit reporting  I have contacted Experian on many occassions i...
# 43706   Credit reporting  There was a hard inquiry from XXXX XXXX XXXX X...
# 122288  Credit reporting  I have a bankruptcy that is reporting on my cr...
# 41345   Credit reporting  To whom it may concern, I mailed a Multiple In...
# 79200   Credit reporting  Hello, Simply I contacted XXXX to ask them to ...
# 38728   Credit reporting  Showing a balance which was paid i XX/XX/XXXX ...
# 101899  Credit reporting  I have been working since XX/XX/XXXX for XXXX ...
# 146104  Credit reporting  Several unauthorized hard inquiries on my cred...
# 46190   Credit reporting  CHEXSYSTEMS ARE REPORTING FRAUDULENT ACCOUNTS ...
# 139626  Credit reporting  I hAve XXXX hard inquiries that I have not don...
# 37714   Credit reporting  I have the same bill reported XXXX times on my...
# 120203  Credit reporting  I have been disputing the late reporting on my...

# %%
model.fit(features, labels)
N = 2
for Product, category_id in sorted(category_to_id.items()):
  indices = np.argsort(model.coef_[category_id])
  feature_names = np.array(tfidf.get_feature_names())[indices]
  unigrams = [v for v in reversed(feature_names) if len(v.split(' ')) == 1][:N]
  bigrams = [v for v in reversed(feature_names) if len(v.split(' ')) == 2][:N]
  print("# '{}':".format(Product))
  print("  . Top unigrams:\n       . {}".format('\n       . '.join(unigrams)))
  print("  . Top bigrams:\n       . {}".format('\n       . '.join(bigrams)))
# Out:
# # 'Bank account or service':
#   . Top unigrams:
#        . bank
#        . scottrade
#   . Top bigrams:
#        . debit card
#        . merchant services
# # 'Checking or savings account':
#   . Top unigrams:
#        . couldn
#        . accessing
#   . Top bigrams:
#        . xx 2018
#        . contacted bank
# # 'Consumer Loan':
#   . Top unigrams:
#        . car
#        . loan
#   . Top bigrams:
#        . auto loan
#        . chrysler capital
# # 'Credit card':
#   . Top unigrams:
#        . card
#        . capital
#   . Top bigrams:
#        . credit card
#        . american express
# # 'Credit card or prepaid card':
#   . Top unigrams:
#        . don
#        . card
#   . Top bigrams:
#        . america did
#        . online statement
# # 'Credit reporting':
#   . Top unigrams:
#        . equifax
#        . experian
#   . Top bigrams:
#        . xxxx bank
#        . trans union
# # 'Credit reporting, credit repair services, or other personal consumer reports':
#   . Top unigrams:
#        . didn
#        . don
#   . Top bigrams:
#        . xxxx xxxx
#        . information opened
# # 'Debt collection':
#   . Top unigrams:
#        . debt
#        . recovery
#   . Top bigrams:
#        . right dispute
#        . reporting foreclosure
# # 'Money transfer, virtual currency, or money service':
#   . Top unigrams:
#        . coinbase
#        . support
#   . Top bigrams:
#        . coinbase xxxx
#        . money online
# # 'Money transfers':
#   . Top unigrams:
#        . moneygram
#        . money
#   . Top bigrams:
#        . western union
#        . money transfer
# # 'Mortgage':
#   . Top unigrams:
#        . mortgage
#        . escrow
#   . Top bigrams:
#        . quicken loans
#        . item remove
# # 'Other financial service':
#   . Top unigrams:
#        . certegy
#        . lexington
#   . Top bigrams:
#        . check cashing
#        . lexington law
# # 'Payday loan':
#   . Top unigrams:
#        . payday
#        . loan
#   . Top bigrams:
#        . pay day
#        . payday loan
# # 'Payday loan, title loan, or personal loan':
#   . Top unigrams:
#        . loan
#        . don
#   . Top bigrams:
#        . matter xx
#        . given correct
# # 'Prepaid card':
#   . Top unigrams:
#        . rushcard
#        . prepaid
#   . Top bigrams:
#        . prepaid card
#        . express serve
# # 'Student loan':
#   . Top unigrams:
#        . navient
#        . nelnet
#   . Top bigrams:
#        . great lakes
#        . sallie mae
# # 'Vehicle loan or lease':
#   . Top unigrams:
#        . vehicle
#        . stealing
#   . Top bigrams:
#        . agreed contract
#        . xxxx ally
# # 'Virtual currency':
#   . Top unigrams:
#        . coinbase
#        . https
#   . Top bigrams:
#        . going transferred
#        . said completed

# %%
from sklearn import metrics
print(metrics.classification_report(y_test, y_pred, target_names=df['Product'].unique()))
# Out:
#                                                                               precision    recall  f1-score   support
#
#                                                             Credit reporting       0.81      0.83      0.82      1994
#                                                                Consumer Loan       0.75      0.65      0.70       644
#                                                              Debt collection       0.81      0.89      0.85      2788
#                                                                     Mortgage       0.91      0.96      0.93      2136
#                                                                  Credit card       0.75      0.82      0.78      1176
#                                                      Other financial service       0.00      0.00      0.00        24
#                                                      Bank account or service       0.78      0.80      0.79       967
#                                                                 Student loan       0.88      0.85      0.86       760
#                                                              Money transfers       0.75      0.51      0.61        94
#                                                                  Payday loan       0.70      0.40      0.51       112
#                                                                 Prepaid card       0.68      0.51      0.58       104
#                           Money transfer, virtual currency, or money service       0.95      0.59      0.73        32
# Credit reporting, credit repair services, or other personal consumer reports       0.74      0.26      0.39       300
#                                                  Checking or savings account       0.00      0.00      0.00        47
#                                                        Vehicle loan or lease       0.00      0.00      0.00        17
#                                                  Credit card or prepaid card       1.00      0.01      0.03        68
#                                                             Virtual currency       0.00      0.00      0.00         2
#                                    Payday loan, title loan, or personal loan       0.00      0.00      0.00        22
#
#                                                                  avg / total       0.81      0.82      0.81     11287
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
