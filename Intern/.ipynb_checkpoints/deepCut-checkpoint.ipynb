# %%
#! pip install deepcut
# Out:
# Collecting deepcut
#   Downloading https://files.pythonhosted.org/packages/c0/30/53a4109fca052b0f69cdb49762f418767b5c09fd3640bbb07810e9b2e71a/deepcut-0.6.1.0.tar.gz (2.0MB)
# Collecting keras>=2.0.0 (from deepcut)
#   Downloading https://files.pythonhosted.org/packages/68/12/4cabc5c01451eb3b413d19ea151f36e33026fc0efb932bf51bcaf54acbf5/Keras-2.2.0-py2.py3-none-any.whl (300kB)
# Requirement already satisfied: pandas in c:\users\chaiy\anaconda3\lib\site-packages (from deepcut)
# Requirement already satisfied: scipy in c:\users\chaiy\anaconda3\lib\site-packages (from deepcut)
# Requirement already satisfied: numpy in c:\users\chaiy\anaconda3\lib\site-packages (from deepcut)
# Requirement already satisfied: scikit-learn in c:\users\chaiy\anaconda3\lib\site-packages (from deepcut)
# Requirement already satisfied: h5py in c:\users\chaiy\anaconda3\lib\site-packages (from deepcut)
# Requirement already satisfied: pyyaml in c:\users\chaiy\anaconda3\lib\site-packages (from keras>=2.0.0->deepcut)
# Requirement already satisfied: six>=1.9.0 in c:\users\chaiy\anaconda3\lib\site-packages (from keras>=2.0.0->deepcut)
# Collecting keras-preprocessing==1.0.1 (from keras>=2.0.0->deepcut)
#   Downloading https://files.pythonhosted.org/packages/f8/33/275506afe1d96b221f66f95adba94d1b73f6b6087cfb6132a5655b6fe338/Keras_Preprocessing-1.0.1-py2.py3-none-any.whl
# Collecting keras-applications==1.0.2 (from keras>=2.0.0->deepcut)
#   Downloading https://files.pythonhosted.org/packages/e2/60/c557075e586e968d7a9c314aa38c236b37cb3ee6b37e8d57152b1a5e0b47/Keras_Applications-1.0.2-py2.py3-none-any.whl (43kB)
# Requirement already satisfied: python-dateutil>=2 in c:\users\chaiy\anaconda3\lib\site-packages (from pandas->deepcut)
# Requirement already satisfied: pytz>=2011k in c:\users\chaiy\anaconda3\lib\site-packages (from pandas->deepcut)
# Building wheels for collected packages: deepcut
#   Running setup.py bdist_wheel for deepcut: started
#   Running setup.py bdist_wheel for deepcut: finished with status 'done'
#   Stored in directory: C:\Users\chaiy\AppData\Local\pip\Cache\wheels\4a\01\e0\7e93820628b45ac21db97398b0475a6df7772d1f274f7d0878
# Successfully built deepcut
# Installing collected packages: keras-preprocessing, keras-applications, keras, deepcut
# Successfully installed deepcut-0.6.1.0 keras-2.2.0 keras-applications-1.0.2 keras-preprocessing-1.0.1
# You are using pip version 9.0.3, however version 10.0.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
#from geopy.distance import great_circle
import pandas as pd
import deepcut as dc

file = pd.read_csv('text_input.csv')
# fo = open("final.txt","w")
Column3= file['Column3']

num = 1

dc.tokenize('วันนี้เป็นวันเสาร์อากาศสดใสไม่มี ฝนตก...235/6to live in bangkok')
# Out:
# Using TensorFlow backend.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-a35f4408291c> in <module>()
#       1 #from geopy.distance import great_circle
#       2 import pandas as pd
# ----> 3 import deepcut as dc
#       4
#       5 file = pd.read_csv('text_input.csv')
#
# C:\Users\chaiy\Anaconda3\lib\site-packages\deepcut\__init__.py in <module>()
#       1 #!/usr/bin/env python
#       2 # encoding: utf-8
# ----> 3 from .deepcut import tokenize, DeepcutTokenizer
#       4 from .train import generate_best_dataset, prepare_feature, train_model, evaluate
#
# C:\Users\chaiy\Anaconda3\lib\site-packages\deepcut\deepcut.py in <module>()
#      10 import scipy.sparse as sp
#      11 import six
# ---> 12 from keras import backend
#      13
#      14 from .model import get_convo_nn2
#
# C:\Users\chaiy\Anaconda3\lib\site-packages\keras\__init__.py in <module>()
#       1 from __future__ import absolute_import
#       2
# ----> 3 from . import utils
#       4 from . import activations
#       5 from . import applications
#
# C:\Users\chaiy\Anaconda3\lib\site-packages\keras\utils\__init__.py in <module>()
#       4 from . import data_utils
#       5 from . import io_utils
# ----> 6 from . import conv_utils
#       7
#       8 # Globally-importable utils.
#
# C:\Users\chaiy\Anaconda3\lib\site-packages\keras\utils\conv_utils.py in <module>()
#       7 from six.moves import range
#       8 import numpy as np
# ----> 9 from .. import backend as K
#      10
#      11
#
# C:\Users\chaiy\Anaconda3\lib\site-packages\keras\backend\__init__.py in <module>()
#      85 elif _BACKEND == 'tensorflow':
#      86     sys.stderr.write('Using TensorFlow backend.\n')
# ---> 87     from .tensorflow_backend import *
#      88 else:
#      89     # Try and load external backend.
#
# C:\Users\chaiy\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py in <module>()
#       3 from __future__ import print_function
#       4
# ----> 5 import tensorflow as tf
#       6 from tensorflow.python.framework import ops as tf_ops
#       7 from tensorflow.python.training import moving_averages
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
##  ติดปัญหา deepcut ไม่รันใน loop ##
dc.tokenize('วันนี้เป็นวันเสาร์อากาศสดใสไม่มี ฝนตก...235/6to live in bangkok')
for text in zip(Column3):
    dc.tokenize('วันนี้เป็นวันเสาร์อากาศสดใสไม่มี ฝนตก...235/6to live in bangkok')
    t = str(text)
    #print (num,'. ',t+'\n')
    if num < 10:
        print (num,'. ',t+'\n')
        #deepcut.tokenize(t+'')
        dc.tokenize(t+'')
        dc.tokenize('วันนี้เป็นวันเสาร์อากาศสดใสไม่มี ฝนตก...235/6to live in bangkok')
    num += 1
# Out:
# 1 .  ('สวัสดีครับเพื่อนๆ..เมื่อวานนี้ผมได้ไปช่วยครอบครัวของคุณ นคร เทียนขำ ซึ่งถูกรถชนแล้วหลบหนีขณะกำลังจะกลับบ้าน คุณ นคร ทำงานที่สำนักเขต คลองเตย ตำแหน่ง เก็บขยะ คุณแม่ก็ทำงานที่เดียวกัน คุณแม่มีหน้าที่กวาดขยะ ตอนนี้คุณแม่ทำงานคนเดียว เพราะคุณ นคร ได้เสียความทรงจำ สมองสั่งงานช้า อึ ฉี่ โดยไม่รู้ตัว ต้องใส่แพมเพิตตลอดเวลาเหตุเกิดเมื่อปีที่แล้ว คุณ นคร ต้องผ่ากระโหลก และนอน รพ เดือนครึ่ง ตอน2เดือนที่แล้วคุณหมอให้ไปใส่กระโหลกเทียม แต่คุณแม่ไม่มีเงินก็เลยยังไม่ได้ใส่ เพราะค่าใช้จ่ายทั้งหมด30,000บาท คุณแม่ก็เลยขอผลัดไปก่อน คุณพ่อเสียไป15ปีที่แล้ว แม่ต้องหาเลี้ยงลูกคนเดียวเงินเดือน12,000บาทหักใช้หนี้สหกรณ์6,000บาทเหลือ6,000บาทเมื่อวานผมให้คุณแม่นัดหมอเพื่อทำการใส่กระโหลกเทียมให้น้องแล้วครับ โดยจะออกค่าใช้จ่ายให้คุณ นคร ทั้งหมด ตอนนี้ คุณ นคร อายุ 30ปี คุณแม่ 50ปี ก็ควต้องดูแลกันและกันไปอีกนานครับ ถ้าเพื่อนๆท่านใดอยากจะช่วยเหลือคุณ นคร ก็ยินดีครับชื่อ บ/ช นาง สมควร พุ่มสงวน ธ.กรุงไทย สาขาเอกมัย  เลขที่ บ/ช 053-0099578 ออมทรัพย์อยู่บ้านเลขที่ 8/270 ซ.อาจณรงค์1 ข.คลองเตยเขต คลองเตย ขอบคุณมากๆครับ',)
#
# 2 .  ('นี่คือภาพคุณ นคร ตอนถูกชนเมื่อปีที่แล้ว เมื่อวานนี้ได้ช่วยเหลือไป15,000บาท อีก2อาทิตย์ คุณ นครจะไปใส่กระโหลกเทียมครับ',)
#
# 3 .  ('สวัสดีครับเพื่อนๆ..วันนี้ผมมาหาอาจารย์ท่านหนึ่งซึ่งเมืิ่อก่อนนี้ท่ามีชื่อเสียงอย่างมากท่านชื่อ กู้เกียรติ นครสวรรค์ ฉายาระนาดเอกและระนาดลอยฟ้า เป็นผู้ที่แต่งเพลงมากมาย แต่งเพลงให้นักร้องดังๆในอดีตเช่น สัญญา พรนารายณ์ เพชร โพธารามขวัญจิต ศรีประจัน ไวพจน์ เพชรสุพรรณ และท่านได้รางวัลมากมาย  แต่ตอนนี้ท่านป่วยและถูกทอดทิ้งให้อยู่คนเดียวในบ้านที่ทรุดโทรมมาก เป็นบ้าน2ชั้นเก่ามากๆ เข้า2คนไม่ได้เพราะบ้านพังแน่นอน ผมได้นั่งคุยกับท่านก็สงสารท่าน ท่านมีลูก1คนที่เลี้ยงมากับมือโดยถูกภรรยาทิ้งไปแต่ก็ทนเลี้ยงมาจนโตแต่ก็มาทิ้งท่านและขโมยเงินที่เก็บเอาไว้2หมื่นบาทไปด้วย ท่านบอกจะเอาเงินที่เก็บไว้ซ่อมบ้าน แต่ลุูกก็ขโมยไปแล้ว ท่านเดินไม่ได้ถนัด เดินได้ช้าๆ ที่บ้านท่านน่ากลัวมากจริงๆไม่รู้ว่าวันไหนจะพังลงมา มีน้ำเน่ารอบๆบ้าน ข้างในบ้านมีแต่กลิ่นเหม็น ท่านไม่ออกไปไหน จะมีชาวบ้านแถวนั้นเอาข้าวมาให้บ้างมาถามบ้างว่าต้องการอะไร วันนี้ผมก็เลยบอกท่านว่าผมจะซ่อมแซมบ้านให้ใหม่ เปลี่ยนทุกอย่างที่ใช้ไม่ได้ออก ทำให้ดีกว่าเดิมและไม่อันตราย โดยเรียกช่างมาตีราคา ก็คงประมาณไม่เกิน50,000บาท ผมได้จ่ายค่ามัดจำเอาไว้ซื้อของก่อน15,000บาท ก็คงจะเริ่มทำวันจันทร์นี้ครับ ท่านดีใจมากๆไม่เคยคิดมาก่อนว่าจะมีวันนี้  เห็นท่านยิ้มได้ผมก็มีความสุขครับ',)
#
# 4 .  ('สวัสดีครับเพื่อนๆ..เมื่อวานนี้ได้เข้าไปช่วยเหลือคุณยาย เวียง(บุญมา ทับชู) อายุ85ปี อยู่คนเดียวมา15ปี ตอนนี้อาศัยบ้านเช่าอยู่ แต่เจ้าของไม่เอาค่าเช่าให้อยู่ฟรี เพราะชอบคุณยายใจบุญ คุณยายชอบเอาอาหารไปเลี้ยงสุนัขและแมวที่ไม่มีเจ้าของ และเลี้ยงแมวตาบอดเอาไว้อีกตัวเพราะมีคนเอามาทิ้ง คุณยายเป็นคนไม่มีตัวตนคุณไม่มีบัตรประชาชน คุณยาย เป็นคนจังหวัดสุโขทัย มาอยู่แถวจรัญเมื่อ40ปีที่แล้ว แต่บัตรประชาชนหาย คุณยายเคยไปถามที่สำนักงานเขตที่บางกอกน้อยให้ on line ไปที่สุโขทัย แต่เจ้าหน้าที่บอกคุณยายตายไปแล้ว ทำบัตรไม่ได้ คุณยายไม่เคยได้รับสิทธิอะไรเลยของผู้สูงอายุ คุณยายอยู่แบบไม่มีตัวตน บ้านที่ยายอยู่ก็ต้องมุดเข้าบ้าน เพราะสถานที่มันเล็กมาก ฝาปิดก็หนัก ยายต้องเอาหัวดันฝาเข้าห้อง ผมคิดว่าผมจะพายายไปทำบัตรที่ประชาชนที่สำนักงานเขตบางกอกน้อยอีกที ไปขอความกรุณาผู้อำนวยการเขตให้ช่วยยาย ผมถามว่าแล้วยายเอาเงินที่ไหนใช้ยายบอกว่ามีคนเขาให้ทีละ20-30 ก็เก็บเอาไว้ เค้าสงสารยาย ผมถามว่ายายใช้เงินเดือนล่ะเท่าไร ยายบอกว่าเดือนล่ะ1พันบาท ถ้าไม่ไปหาหมอก็พอ ยายต้องไปหาหมอที่คลีนิก เพราะไป รพ ไม่ได้ ไม่มีบัตรผมเลยบอกยายว่าผมจะดูแลยายเองโดยให้ยายใช้ทุกเดือน เดือนละ2พันบาท และจะไปทำบัตรประชาชนด้วย ยายดีใจน้ำตาไหลเลย บอกว่าช่วยยายด้วยนะ ก็คงไม่เกินอาทิตย์นี่้ครับจะพายายไปทำบัตร ก็ต้องขอความกรุณาท่าน ผอ สำนักงานเขตด้วยนะครับ กราบขอบพระคุณครับ(ผมจะเอายายไปอยู่ที่นครปฐมแต่ยายไม่ไปครับเป็นห่วงแมวกับสุนัข)',)
#
# 5 .  ('สวัสดีครับเพื่อนๆ..เมื่อวานนี้ผมได้ไปหาน้องอุ้มหรือด.ญ วราลักษณ์ พาณิชย์ อายุ 6ปี อยู่ อนุบาล3น้องอุ้มมีอาการผิดปกติทางร่างกายอย่างมาก เมื่อก่อนตอนอายุ4-5ปีน้องอุ้มมีน้ำหนักมากถึง34กกแต่มาเมื่อปีที่แล้วน้องอุ้มน้ำหนักเหลือเพียง16กกมีแต่หนังหุ้มกระดูก ทุกวันนี้น้องก็ยังคงทานข้าวได้เหมือนปกติ แต่ร่างกายก็ผอมลงเลยๆ คุณแม่พาไปหาหมอแล้วหลายครั้งแต่ก็หาสาเหตุไม่ได้ น้องไม่มีอาการเจ็บปวด แต่จะไม่ค่อยมีแรง ครอบครัวฐานะยากจนคุณพ่อเป็น ยาม คุณแม่ขายขันขายกะแป๋งพาสติกแถวตลาดนัด ต้องนั่งรถเมล์ไปขาย ุคณพ่อขี่จักรยานไปทำงาน ผมวานผมก็เลยอาสาน้องว่าจะลองปรึกษาคุณหมอที่ศิริราชดูครับ ว่าจะสามารถช่วยน้องเขาได้มั้ย ถ้าได้ก็จะไปรับน้องมารักษาอีกทีน้องไม่ค่อยได้ทานนมเท่าไร ร่างกายน้องไม่มีเนิื้อเลยครับ ก้นก็ไม่มี เหี่ยวทั้งตัว คุณแม่พาไปทุกที่ทั้งหมอปัจจุบันและหมอพระและไสย์ยาศาตร์ แต่น้องก็ไม่ดีขีึ้น ถ้าคุณหมอที่ศิริราชจะรับน้องไปรักษาผมจะดำเนินการให้ครับ เมื่อวานช่วยน้องไป10,000บาทครับแต่ถ้าท่านใดอยากจะช่วยเหลือก็เชิญนะครับบ/ช ชื่อ กฤติยา สุขวินัย ธ.ไทยพาณิชย์ ออมทรัพย์เลขที่ บ/ช 403-7-82719-2 ท่านใดอยากโทรสอบถามรายละเอียด 081-6348136 ขอบคุณมากๆครับ',)
#
# 6 .  ('สวัสดีครับเพื่อนๆ..เมื่อวานนี้ผมได้มีโอกาสได้เข้าไปช่วยเหลือน้อง ป๋องแป๋ง หรือ ด.ช ปัณณฑัต การะเกตุ  อายุ11ปี อาศัยอยู่กับยายกับแม่ ส่วนพ่อทิ้งไปเมื่อรู้น้องพิการ น้องเกิดมามีนิ้วเท้าติดกันและนิ้งเท้าไม่ครบ แถมมิหน่ำซ้ำน้องยังเป็นโรคแพ้ภูมิตัวเอง คือมีแผลขึ้นตามตัวส่วนมากที่ขา เป็นแผลแบบผุผองมีน้ำเหลืองไหลเยิ้ม ตามร่างกาย เป็นที่น่ารังเกลียดของเพื่อนๆบางคน น้องต้องอดทนและต่อสู้กับตัวเองมาถึง 10ปี คุณยายพาไปหาหมอที่อนามัย ไม่ไม่หาย ไปมาหลายที่ในเขตของจังหวัดปทุมธานี จนหมดเงินรักษาแล้ว ผมก็เลยอาสาจะพาน้องมารักษาที่ รพ พระมงกุฎครับ ตอนนี้กำลังปรึกษาคุณหมออยู่ครับ น้องน่าสงสารมากครับ เท้าก็พิการ ผิวหนังยังเป็นแผลอีก พอผมพูดให้กำลังใจน้อง น้องก็ร้องไห้ออกมาแบบน้อยใจตัวเอง เมื่อวานนี้ผมเอาเงินให้น้อง10,000บาทเอาไว้ให้น้องเป็นค่าใช้จ่าย ถ้าเพื่อนๆท่านใดอยากจะช่วยเหลือน้องก็เชิญเลยนะครับ ชื่อ บ/ช นาง บุญธรรมการะเกตุ ธ.กสิกรไทย สาขาโลตัสวัดลาดปลาดุกเลขที่ บ/ช 573-2-07594-3 ออมทรัพย์คุณแม่เป็นพนักงานอยู่ บิ๊กซี  กราบขอบคุณมากๆครับ',)
#
# 7 .  ('สวัสดีครับเพื่อนๆ..ตอนนี้ผมอยู่ที่นอนของคุณตาวิชัย ที่ถูกลูกนำมาทิ้งแล้วนะครับ แต่ตอนนี้คุณตาถูกนำตัวส่ง รพ สมเด็จ ที่ศรีราชาแล้วครับ โดยมูลนิธิสว่างบริบูรณ์ เป็นผู้นำส่งครับ เพื่อนๆทุกท่านต้องห่วงนะครับ ตอนนี้ผมกำลังไปเยี่ยมคุณตาที่ รพได้ความคืบหน้าอย่างไรจะแจ้งให้ทราบอีกที..ถ้าลูกไม่ออกมา ผมก็จะพาคุณตาไปดูแลที่นครปฐมเองครับ แล้วจะแจ้งให้ทราบครับ',)
#
# 8 .  ('เพื่อนๆครับ..ตอนนี้ผมอยู่ที่ รพ สมเด็จฯ ที่ศรีราชาแล้วครับ ตอนนี้คุณตาปลอดภัยแล้วครับ หน้าตาสดใส ตอนนี้นอนให้น้ำเกลืออยู่ครับ และที่สำคัญคือภรรยาของคุณตามาเยี่ยมแล้วครับ ภรรยาคนแรกที่เลิกกันไปเมื่อ40ปีที่แล้วแล้วก็มีลูกด้วยกัน1คน แต่ลูกอยู่กระบี่ จะมาเยี่ยมพรุ่งนี้ครับแล้วบอกว่าไม่รู้เรื่องที่พ่อโดนทิ้งแบบนี้ คิดว่าอยู่สุขสบายกับภรรยาใหม่ ถ้ารู้ว่าถูกทอดทิ้งก็คงเอาพ่อไปอยู่ด้วยแล้วเพื่อนๆครับถ้าสังเกตุนิ้วมือด้านซ้ายนิ้วนางของลุงจะเป็นสีดำอยู่ครึ่งนิ้ว นั้นคือไม่มีใครเห็นว่าลุงเอาหนังยางไปรัดไว้ตั้งแต่เมื่อไร ทำให้นิ้วเน่าและตายลุงพูดไม่ได้ อาการคือเคี้ยวฟันอยู่ตลอดเวลา และผู้หญิงที่เห็นเสื้อสีแดง น้องคนนี้เป็นคนpost เรื่องของคุณตาครับ น้องไม่ใช่ญาติคุณตาแต่สงสาร เลยอยากให้มีใครมาช่วยเหลือคุณตา ขอบคุณมากๆครับน้องเอ ทำให้เราทราบเรื่องคุณตา และทำให้ภรรยาและลูกได้เจอคุณตาอีกครั้ง ขอบคุณเพื่อนๆทุกท่านที่ทำให้สังคมของเราน่าอยู่มากๆ เพราะถึงอย่างไรเราก็คนไทยด้วยกันครับ',)
#
# 9 .  ('สวัสดีครับเพื่อนๆ..เมื่อวานนี้ผมได้เข้ามาเยี่ยมน้องแบงค์ ที่ถูกรุมทำร้ายเมื่อเดิือน มกราคม ที่ผ่านมาน้องถูกฟันนิ้วมือขาด6นิ้ว และถูกแทงทะลุปอดและที่หัวที่ด้านหลัง เย็บกว่า200เข็ม แต่ตอนนี้หมอต่อน้ิวให้น้องได้4นิ้วด้วนไป2นิ้ว แต่ส่วนที่ต่อยังใช้งานไม่ได้ ส่วนแขนด้านซ้ายก็ใช้งานไม่ได้เพราะโดนฟันจนเอ็นขาด ตอนนี้กลับมารักษาตัวอยู่ที่บ้านได้10วันแล้วยังไม่มีหน่วยงานไหนมาช่วยค่ารักษา น้องใช้บัตร30บาทรักษา แต่ต้องมีค่าส่วนเกินกว่า70,000บาท คุณแม่เป็นกระเป๋ารถเมล์ คุณพ่อแยกทางกันเมื่อวานผมช่วยเหลือน้องไป20,000บาท น้องอยากกลับไปเรียนแต่มือไม่สามารถเขียนได้ ถ้าเพื่อนๆท่านใดอยากจะช่วยเหลือน้องแบงค์ก็เชิญเลยครับ ชื่อ บ/ช นางธันยา นุริตานนท์ ธ.กรุงไทยสาขาปากน้ำ เลขที่ บ/ช 219-0-26787-0 ออมทรัพย์ กราบขอบคุณครับวันนี้ไปเวียนเทียนกันนะครับ ผมไปที่วัดทุ่งเศรษฐีที่รามคำแหง2 ครับ',)

# %%
import deepcut

deepcut.tokenize('วันนี้เป็นวันเสาร์อากาศสดใสไม่มี ฝนตก...235/6to live in bangkok')
# Out:
# ['วัน',
#  'นี้',
#  'เป็น',
#  'วัน',
#  'เสาร์',
#  'อากาศ',
#  'สดใส',
#  'ไม่',
#  'มี',
#  ' ',
#  'ฝน',
#  'ตก',
#  '...',
#  '235',
#  '/',
#  '6',
#  'to',
#  ' ',
#  'live',
#  ' ',
#  'in',
#  ' ',
#  'bangkok']

# %%
deepcut.tokenize('ตัดคำได้ดีมาก')
# Out:
# ['ตัด', 'คำ', 'ได้', 'ดี', 'มาก']

# %%
deepcut.tokenize('พี่บิณฑ์จำเรื่องคุณยายที่พาหลานหนีมาจากลูกชายตัวเองจากบ้านที่สุรินทร์เพราะยายทนลูกชายที่เมาแล้วชอบทำร้ายคุณยายและหลานๆไม่ไหว ได้มั้ยครับ ตอนนี้มีคนไปเจอคุณยายแล้วรับ ยายยังตระเวนเก็บขวด เก็บกระป๋องอยู่แถวๆหน้าบิ๊กซีบางใหญ่อยู่เลยครับ ขอความกรุณาจากพี่บิณฑ์เถอะครับ ผมก็ไม่รู้ว่าเรื่องคุณยายคนนี้ มันมีอะไรดลจิตใจผมแปลกๆ ถ้ารบกวนมากไปขออภัยจริงๆครับ ช่วยยายด้วยครับ เบอร์ยายครับ 086-0156997')
# Out:
# ['พี่บิณฑ์',
#  'จำ',
#  'เรื่อง',
#  'คุณ',
#  'ยาย',
#  'ที่',
#  'พา',
#  'หลาน',
#  'หนี',
#  'มา',
#  'จาก',
#  'ลูก',
#  'ชาย',
#  'ตัว',
#  'เอง',
#  'จาก',
#  'บ้าน',
#  'ที่',
#  'สุรินทร์',
#  'เพราะ',
#  'ยาย',
#  'ทน',
#  'ลูก',
#  'ชาย',
#  'ที่',
#  'เมา',
#  'แล้ว',
#  'ชอบ',
#  'ทำร้าย',
#  'คุณ',
#  'ยาย',
#  'และ',
#  'หลาน',
#  'ๆ',
#  'ไม่',
#  'ไหว',
#  ' ',
#  'ได้',
#  'มั้ย',
#  'ครับ',
#  ' ',
#  'ตอน',
#  'นี้',
#  'มี',
#  'คน',
#  'ไป',
#  'เจอ',
#  'คุณ',
#  'ยาย',
#  'แล้ว',
#  'รับ',
#  ' ',
#  'ยาย',
#  'ยัง',
#  'ตระเวน',
#  'เก็บ',
#  'ขวด',
#  ' ',
#  'เก็บ',
#  'กระป๋อง',
#  'อยู่',
#  'แถว',
#  'ๆ',
#  'หน้า',
#  'บิ๊กซี',
#  'บาง',
#  'ใหญ่',
#  'อยู่',
#  'เลย',
#  'ครับ',
#  ' ',
#  'ขอ',
#  'ความ',
#  'กรุณา',
#  'จาก',
#  'พี่บิณฑ์',
#  'เถอะ',
#  'ครับ',
#  ' ',
#  'ผม',
#  'ก็',
#  'ไม่',
#  'รู้',
#  'ว่า',
#  'เรื่อง',
#  'คุณ',
#  'ยาย',
#  'คน',
#  'นี้',
#  ' ',
#  'มัน',
#  'มี',
#  'อะไร',
#  'ดล',
#  'จิตใจ',
#  'ผม',
#  'แปลก',
#  'ๆ',
#  ' ',
#  'ถ้า',
#  'รบกวน',
#  'มาก',
#  'ไป',
#  'ขอ',
#  'อภัย',
#  'จริง',
#  'ๆ',
#  'ครับ',
#  ' ',
#  'ช่วย',
#  'ยาย',
#  'ด้วย',
#  'ครับ',
#  ' ',
#  'เบอร์ยาย',
#  'ครับ',
#  ' ',
#  '086',
#  '-',
#  '0156997']

# %%
deepcut.tokenize('สวัสดีครับเพื่อนๆ..วันนี้ได้มีโอกาสมาช่วยน้องภูวนารถ อสุนี ณ.อยุธยา อายุ25ปี อาชีพขับวินมอเตอร์ไซด์ มีลูก2คนอายุ7ขวบกับ8ขวบ อยู่บ้านเช่าที่ ชุมชนกรุงเทพนนท์ซอย12 เดือนละ1,400บาทเรื่องมีอยู่ว่า ย้อนกลับไปเมื่อ1ปี3เดือนน้องกล้วยได้เดินอยู่แถวบ้านอยู่ๆก็ล้มลงโดยไม่ทราบสาเหตุและไม่สามารถพูดได้เดินไม่ได้มือก็ทำอะไรไม่ได้ถ้าจะพูดถึงน้อง น้องก็น้องไห้อย่างเดียว น้องฟังได้รับรู้ทุกอย่างแต่ไม่สามารถพูดได้ ถ้าเป็นผมก็คงจะอกแตกตายเพราะมันต้องอึดอัดมาก น้องเป็นคนหาเงินส่งลูกเรียนจ่ายค่าเช่าบ้านและค่าน้ำค่าไฟตอนนี้ปีกว่าน้องไม่ได้ทำอะไรเลย ตอนนี้ภรรยาของน้องต้องออกไปเป็นแม่บ้านที่บริษัทแห่งนึง ตอนเช้าแม่ของน้องจะดูแลส่วนกลางคืนภรรยาจะมาดูแลน้องเคยไปหาหมอรักษาแต่หมอบอกว่าสมองบวมและได้ไปอีกที่นึงหมอบอกสมองตีบ ตอนนี้น้องมาอยู่ที่บ้านครับ ผมพูดอะไรน้องก็ร้องไห้เสียงดังมากผมช่วยน้องไป15,000บาทครับตอนนี้ก็แล้วแต่เพื่อนๆนะครับ ผมเองก็ไม่อยากรบกวนทุกๆวันหรอกครับแต่ทำไงได้ครับ คนต้องการความช่วยเหลือมีทุกวันครับ เข้าใจผมนะครับ และผมรับรองว่าทุกเคสเป็นเรื่องจริงครับ ผมมาด้วยตัวเองรับรองไม่มีมิจฉาชีพครับ  ถ้าเพื่อนอยากจะช่วยน้องเชิญเลยครับชื่อ บ/ช อังคณา ฉายา ธ.ไทยพาณิช สาขานนทบุรีเลขที่ บ/ช 382-2-19372-8 ออมทรัพย์เบอร์ติดต่อ 083-0380393 (ชื่อ บ/ช เป็นของภรรยาครับ)ขอบคุณครับ')
# Out:
# ['สวัสดี',
#  'ครับ',
#  'เพื่อน',
#  'ๆ',
#  '..',
#  'วัน',
#  'นี้',
#  'ได้',
#  'มี',
#  'โอกาส',
#  'มา',
#  'ช่วย',
#  'น้องภูวนารถ',
#  ' อสุนี ณ.อยุธยา',
#  ' ',
#  'อายุ',
#  '25',
#  'ปี',
#  ' ',
#  'อาชีพ',
#  'ขับ',
#  'วิน',
#  'มอเตอร์ไซด์',
#  ' ',
#  'มี',
#  'ลูก',
#  '2',
#  'คน',
#  'อายุ',
#  '7',
#  'ขวบ',
#  'กับ',
#  '8',
#  'ขวบ',
#  ' ',
#  'อยู่',
#  'บ้าน',
#  'เช่า',
#  'ที่',
#  ' ',
#  'ชุมชนกรุงเทพนนท์',
#  'ซอย',
#  '12',
#  ' ',
#  'เดือน',
#  'ละ',
#  '1',
#  ',',
#  '400',
#  'บาท',
#  'เรื่อง',
#  'มี',
#  'อยู่',
#  'ว่า',
#  ' ',
#  'ย้อนกลับ',
#  'ไป',
#  'เมื่อ',
#  '1',
#  'ปี',
#  '3',
#  'เดือน',
#  'น้องกล้วย',
#  'ได้',
#  'เดิน',
#  'อยู่',
#  'แถว',
#  'บ้าน',
#  'อยู่',
#  'ๆ',
#  'ก็',
#  'ล้ม',
#  'ลง',
#  'โดย',
#  'ไม่',
#  'ทราบ',
#  'สาเหตุ',
#  'และ',
#  'ไม่',
#  'สามารถ',
#  'พูด',
#  'ได้',
#  'เดิน',
#  'ไม่',
#  'ได้',
#  'มือ',
#  'ก็',
#  'ทำ',
#  'อะไร',
#  'ไม่',
#  'ได้',
#  'ถ้า',
#  'จะ',
#  'พูด',
#  'ถึง',
#  'น้อง',
#  ' ',
#  'น้อง',
#  'ก็',
#  'น้องไห้',
#  'อย่าง',
#  'เดียว',
#  ' ',
#  'น้อง',
#  'ฟัง',
#  'ได้',
#  'รับ',
#  'รู้',
#  'ทุก',
#  'อย่าง',
#  'แต่',
#  'ไม่',
#  'สามารถ',
#  'พูด',
#  'ได้',
#  ' ',
#  'ถ้า',
#  'เป็น',
#  'ผม',
#  'ก็',
#  'คง',
#  'จะ',
#  'อกแตก',
#  'ตาย',
#  'เพราะ',
#  'มัน',
#  'ต้อง',
#  'อึดอัด',
#  'มาก',
#  ' ',
#  'น้อง',
#  'เป็น',
#  'คน',
#  'หา',
#  'เงิน',
#  'ส่ง',
#  'ลูก',
#  'เรียน',
#  'จ่าย',
#  'ค่า',
#  'เช่า',
#  'บ้าน',
#  'และ',
#  'ค่า',
#  'น้ำ',
#  'ค่า',
#  'ไฟ',
#  'ตอน',
#  'นี้',
#  'ปี',
#  'กว่า',
#  'น้อง',
#  'ไม่',
#  'ได้',
#  'ทำ',
#  'อะไร',
#  'เลย',
#  ' ',
#  'ตอน',
#  'นี้',
#  'ภรรยา',
#  'ของ',
#  'น้อง',
#  'ต้อง',
#  'ออก',
#  'ไป',
#  'เป็น',
#  'แม่บ้าน',
#  'ที่',
#  'บริษัท',
#  'แห่ง',
#  'นึง',
#  ' ',
#  'ตอน',
#  'เช้า',
#  'แม่',
#  'ของ',
#  'น้อง',
#  'จะ',
#  'ดูแล',
#  'ส่วน',
#  'กลาง',
#  'คืน',
#  'ภรรยา',
#  'จะ',
#  'มา',
#  'ดูแล',
#  'น้อง',
#  'เคย',
#  'ไป',
#  'หา',
#  'หมอ',
#  'รักษา',
#  'แต่',
#  'หมอ',
#  'บอก',
#  'ว่า',
#  'สมอง',
#  'บวม',
#  'และ',
#  'ได้',
#  'ไป',
#  'อีก',
#  'ที่',
#  'นึง',
#  'หมอ',
#  'บอก',
#  'สมอง',
#  'ตีบ',
#  ' ',
#  'ตอน',
#  'นี้',
#  'น้อง',
#  'มา',
#  'อยู่',
#  'ที่',
#  'บ้าน',
#  'ครับ',
#  ' ',
#  'ผม',
#  'พูด',
#  'อะไร',
#  'น้อง',
#  'ก็',
#  'ร้องไห้',
#  'เสียง',
#  'ดัง',
#  'มาก',
#  'ผม',
#  'ช่วย',
#  'น้อง',
#  'ไป',
#  '15',
#  ',',
#  '000',
#  'บาท',
#  'ครับ',
#  'ตอน',
#  'นี้',
#  'ก็',
#  'แล้วแต่',
#  'เพื่อน',
#  'ๆ',
#  'นะ',
#  'ครับ',
#  ' ',
#  'ผม',
#  'เอง',
#  'ก็',
#  'ไม่',
#  'อยาก',
#  'รบกวน',
#  'ทุก',
#  'ๆ',
#  'วัน',
#  'หรอก',
#  'ครับ',
#  'แต่',
#  'ทำไง',
#  'ได้',
#  'ครับ',
#  ' ',
#  'คน',
#  'ต้องการ',
#  'ความ',
#  'ช่วยเหลือ',
#  'มี',
#  'ทุก',
#  'วัน',
#  'ครับ',
#  ' ',
#  'เข้าใจ',
#  'ผม',
#  'นะ',
#  'ครับ',
#  ' ',
#  'และ',
#  'ผม',
#  'รับรอง',
#  'ว่า',
#  'ทุก',
#  'เคส',
#  'เป็น',
#  'เรื่อง',
#  'จริง',
#  'ครับ',
#  ' ',
#  'ผม',
#  'มา',
#  'ด้วย',
#  'ตัว',
#  'เอง',
#  'รับรอง',
#  'ไม่',
#  'มี',
#  'มิจฉา',
#  'ชีพ',
#  'ครับ',
#  ' ',
#  ' ',
#  'ถ้า',
#  'เพื่อน',
#  'อยาก',
#  'จะ',
#  'ช่วย',
#  'น้อง',
#  'เชิญ',
#  'เลย',
#  'ครับ',
#  'ชื่อ',
#  ' ',
#  'บ/',
#  'ช',
#  ' ',
#  'อังคณา ฉายา',
#  ' ',
#  'ธ.ไทยพาณิช สาขานนทบุรี',
#  'เลข',
#  'ที่',
#  ' ',
#  'บ/',
#  'ช',
#  ' ',
#  '382',
#  '-',
#  '2',
#  '-',
#  '19372',
#  '-',
#  '8',
#  ' ',
#  'ออมทรัพย์เบอร์',
#  'ติดต่อ',
#  ' ',
#  '083',
#  '-',
#  '0380',
#  '393',
#  ' ',
#  '(',
#  'ชื่อ',
#  ' ',
#  'บ/',
#  'ช',
#  ' ',
#  'เป็น',
#  'ของ',
#  'ภรรยา',
#  'ครับ',
#  ')',
#  'ขอบคุณ',
#  'ครับ']

# %%
from geopy.distance import great_circle
import pandas as pd
import deepcut

file = pd.read_csv('text_input.csv')
# fo = open("final.txt","w")
Column3= file['Column3']

num = 1
deepcut.tokenize('วันนี้เป็นวันเสาร์อากาศสดใสไม่มี ฝนตก...235/6to live in bangkok')
for text in zip(Column3):
    t = str(text)
    #print (num,'. ',t+'\n')
    if num < 10:
        #print (num,'. ',t+'\n')
        #deepcut.tokenize(t+'')
        deepcut.tokenize('วันนี้เป็นวันเสาร์อากาศสดใสไม่มี ฝนตก...235/6to live in bangkok')
    num += 1
